#   Downloading tf_keras-2.16.0-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      --------- ------------------------------ 0.4/1.7 MB 13.5 MB/s eta 0:00:01
#      ------------------- -------------------- 0.8/1.7 MB 13.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.3/1.7 MB 13.3 MB/s eta 0:00:01
#      -------------------------------------- - 1.7/1.7 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from keras_bert>=0.86.0->ktrain) (1.24.2)
# Collecting keras-transformer==0.40.0
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-pos-embd==0.13.0
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-multi-head==0.29.0
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-layer-normalization==0.16.0
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-position-wise-feed-forward==0.8.0
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-embed-sim==0.10.0
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keras-self-attention==0.51.0
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cycler>=0.10 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.0.0->ktrain) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.0.1->ktrain) (2022.7.1)
# Collecting regex>2016
#   Downloading regex-2023.12.25-cp310-cp310-win_amd64.whl (269 kB)
#      ---------------------------------------- 0.0/269.5 kB ? eta -:--:--
#      --------------------- ---------------- 153.6/269.5 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 269.5/269.5 kB 4.1 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.19.3
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#      ---------------------------------------- 0.0/346.4 kB ? eta -:--:--
#      --------------------- ---------------- 194.6/346.4 kB 3.9 MB/s eta 0:00:01
#      -------------------------------------- 346.4/346.4 kB 5.3 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting tqdm>=4.27
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#      ---------------------------------------- 78.3/78.3 kB 4.3 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.2-cp310-none-win_amd64.whl (269 kB)
#      ---------------------------------------- 0.0/269.5 kB ? eta -:--:--
#      ---------------------------- --------- 204.8/269.5 kB 6.1 MB/s eta 0:00:01
#      -------------------------------------- 269.5/269.5 kB 5.5 MB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.2-cp310-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#      --- ------------------------------------ 0.2/2.2 MB 5.1 MB/s eta 0:00:01
#      ------- -------------------------------- 0.4/2.2 MB 4.9 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.6/2.2 MB 5.1 MB/s eta 0:00:01
#      -------------- ------------------------- 0.8/2.2 MB 5.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.0/2.2 MB 5.7 MB/s eta 0:00:01
#      --------------------- ------------------ 1.2/2.2 MB 5.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.2/2.2 MB 5.6 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.6/2.2 MB 5.6 MB/s eta 0:00:01
#      -------------------------------- ------- 1.8/2.2 MB 5.4 MB/s eta 0:00:01
#      ------------------------------------ --- 2.0/2.2 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 5.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 5.4 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
#      ---------------------------------------- 0.0/145.3 kB ? eta -:--:--
#      -------------------------------------- 145.3/145.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->ktrain) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->ktrain) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->ktrain) (2.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->ktrain) (1.11.4)
# Collecting tensorflow<2.17,>=2.16
#   Downloading tensorflow-2.16.1-cp310-cp310-win_amd64.whl (2.1 kB)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from tika->ktrain) (65.5.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.3.0-py3-none-any.whl (171 kB)
#      ---------------------------------------- 0.0/171.9 kB ? eta -:--:--
#      -------------------------------------- 171.9/171.9 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers<=4.37.2->ktrain) (4.8.0)
# Collecting tensorflow-intel==2.16.1
#   Downloading tensorflow_intel-2.16.1-cp310-cp310-win_amd64.whl (376.9 MB)
#      ---------------------------------------- 0.0/376.9 MB ? eta -:--:--
#      ---------------------------------------- 0.2/376.9 MB 5.1 MB/s eta 0:01:14
#      ---------------------------------------- 0.4/376.9 MB 5.5 MB/s eta 0:01:09
#      ---------------------------------------- 0.5/376.9 MB 5.7 MB/s eta 0:01:07
#      ---------------------------------------- 0.7/376.9 MB 5.7 MB/s eta 0:01:06
#      ---------------------------------------- 0.9/376.9 MB 5.2 MB/s eta 0:01:13
#      ---------------------------------------- 1.1/376.9 MB 5.2 MB/s eta 0:01:12
#      ---------------------------------------- 1.3/376.9 MB 5.4 MB/s eta 0:01:11
#      ---------------------------------------- 1.5/376.9 MB 5.4 MB/s eta 0:01:10
#      ---------------------------------------- 1.6/376.9 MB 5.2 MB/s eta 0:01:13
376.9 MB 11.9 MB/s eta 0:00:23
#      ---------- -------------------------- 109.1/376.9 MB 11.9 MB/s eta 0:00:23
#      ---------- -------------------------- 109.5/376.9 MB 11.7 MB/s eta 0:00:23
#      ---------- -------------------------- 109.7/376.9 MB 11.7 MB/s eta 0:00:23
#      ---------- -------------------------- 110.0/376.9 MB 11.5 MB/s eta 0:00:24
#      ---------- -------------------------- 110.5/376.9 MB 11.7 MB/s eta 0:00:23
#      ---------- -------------------------- 110.9/376.9 MB 11.5 MB/s eta 0:00:24
#      ---------- -------------------------- 111.3/376.9 MB 11.5 MB/s eta 0:00:24
# ...
#      ------------------------------------ --- 5.1/5.5 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------  5.5/5.5 MB 12.1 MB/s eta 0:00:01
#      ---------------------------------------- 5.5/5.5 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (0.2.0)
# Collecting keras>=3.0.0
#   Downloading keras-3.0.5-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---------------- ----------------------- 0.4/1.0 MB 13.1 MB/s eta 0:00:01
#      -------------------------------- ------- 0.8/1.0 MB 10.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (2.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (0.31.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (0.5.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (2.3.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (3.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (3.3.0)
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp310-cp310-win_amd64.whl (127 kB)
#      ---------------------------------------- 0.0/127.8 kB ? eta -:--:--
#      -------------------------------------- 127.8/127.8 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (4.23.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (1.59.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (16.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (1.6.3)
# Requirement already satisfied: colorama in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers<=4.37.2->ktrain) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (0.38.4)
# Collecting rich
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#      ------------------------------------- 240.7/240.7 kB 15.4 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp310-cp310-win_amd64.whl (101 kB)
#      ---------------------------------------- 0.0/101.3 kB ? eta -:--:--
#      ---------------------------------------- 101.3/101.3 kB ? eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (3.5.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (2.1.3)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#      ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras->ktrain) (2.14.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, jieba, langdetect, tika
#   Building wheel for ktrain (setup.py): started
#   Building wheel for ktrain (setup.py): finished with status 'done'
#   Created wheel for ktrain: filename=ktrain-0.41.2-py3-none-any.whl size=25317122 sha256=340d5cc89311819b80accfcb0fc0fecb3ff2841d7a37daecaf1052f2ba12dd11
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\35\7e\6e\0a327a2a8202df0c37b71dd3b74cc5395747cd236440dff3ea
#   Building wheel for keras_bert (setup.py): started
#   Building wheel for keras_bert (setup.py): finished with status 'done'
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33544 sha256=3790003fa1eff16538d060694c48ed2a0fdd6605c478830854faa7e37c7272aa
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\89\0c\04\646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py): started
#   Building wheel for keras-transformer (setup.py): finished with status 'done'
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12313 sha256=e2ad6474903aceb77c20453b4f092955a0714a1f76320c34487fbfbe49d5feec
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\f2\cb\22\75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py): started
#   Building wheel for keras-embed-sim (setup.py): finished with status 'done'
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3961 sha256=46911ec4b66ab737ef27b3c9af0680903de49b112ce1139158cbedeaffd330e3
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\82\32\c7\fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py): started
#   Building wheel for keras-layer-normalization (setup.py): finished with status 'done'
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4669 sha256=c85f638d49669f0c502a299a3b26f1561fa0cdd50bd4594a7f964c6921b9e412
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\ed\3a\4b\21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py): started
#   Building wheel for keras-multi-head (setup.py): finished with status 'done'
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=15005 sha256=1e13197181c7588f544c1936dd8ac2c6ed2b0ac677d9c0f36445290ade80d8f4
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\cb\23\4b\06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py): started
#   Building wheel for keras-pos-embd (setup.py): finished with status 'done'
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6962 sha256=d3fc439a5abdcbec892921eba263c4c81df112981a3e78214374c0bde228006c
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\78\07\1b\b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py): started
#   Building wheel for keras-position-wise-feed-forward (setup.py): finished with status 'done'
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4983 sha256=b65fa070b9b1359e4a24b1713500b24c8c0e387c80419569d8810af2d78c16c1
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\c1\6a\04\d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py): started
#   Building wheel for keras-self-attention (setup.py): finished with status 'done'
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18915 sha256=e1c30922b1707fe5846d079ec854d9d074b125ed78d89c047a8bde0a7c66223b
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\b8\f7\24\607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for jieba (setup.py): started
#   Building wheel for jieba (setup.py): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314474 sha256=6285f8b307828c12d3bd99275b905998cc87a94f7c59c8314a6e50713d759674
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\c9\69\31\d56d90b22a1777b0b231e234b00302a55be255930f8bd92dcd
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993253 sha256=816cfb0252b5b36caf58a4e23d76bb4217034b01d2b5bbfb1565a6027faa319e
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\95\03\7d\59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py): started
#   Building wheel for tika (setup.py): finished with status 'done'
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32692 sha256=91b7346342a0b2e6e6280e464b3f6eab2b6d73cd065bde17d572391d847257c8
#   Stored in directory: c:\users\ogabr\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\5f\71\c7\b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention jieba langdetect tika
# Installing collected packages: whoosh, sentencepiece, namex, jieba, dm-tree, tqdm, safetensors, regex, pyyaml, ml-dtypes, mdurl, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, fsspec, filelock, fastprogress, chardet, tika, tensorboard, syntok, markdown-it-py, keras-multi-head, huggingface-hub, tokenizers, rich, keras-transformer, transformers, keras_bert, keras, tensorflow-intel, tensorflow, tf_keras, ktrain
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.15.0
#     Uninstalling tensorflow-intel-2.15.0:
#       Successfully uninstalled tensorflow-intel-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed chardet-5.2.0 dm-tree-0.1.8 fastprogress-1.0.3 filelock-3.13.1 fsspec-2024.3.0 huggingface-hub-0.21.4 jieba-0.42.1 keras-3.0.5 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.41.2 langdetect-1.0.9 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.7 pyyaml-6.0.1 regex-2023.12.25 rich-13.7.1 safetensors-0.4.2 sentencepiece-0.2.0 syntok-1.4.4 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 tf_keras-2.16.0 tika-2.6.0 tokenizers-0.15.2 tqdm-4.66.2 transformers-4.37.2 whoosh-2.7.4
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\ogabr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
os.environ['DISABLE_V2_BEHAVIOR'] = '1'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import ktrain
from ktrain import vision as vis
import numpy as np
import pandas as pd
import shutil
import re
import random

# %% [markdown]
# # Unzip images

# %%
import zipfile
with zipfile.ZipFile("beans.zip","r") as zip_ref:
    zip_ref.extractall("./")

# %% [markdown]
# # Rename files according to parameter

# %%
os.makedirs('/content/a/')
os.makedirs('/content/b/')
os.makedirs('/content/L/')

# %%
dt = pd.read_csv('/content/beans.csv')
dt.head()

# %%
dt[dt['filename'].isin(['e41', 'e58'])]

# %%
print(dt.iloc[123:126,[2,3,4]].mean())
print(dt.iloc[174:177,[2,3,4]].mean())

# %% [markdown]
# ### Selecting the parameter (L, a, or b)

# %%
parameter = 'a'
dtP = dt.groupby(['filename'], as_index=False ).max()
dtP = dtP[['filename', parameter]]
dtP.head()

# %% [markdown]
# ### Renaming images files according to the selected parameter

# %%
import shutil

# %%
for i in range(dtP.shape[0]):
  shutil.copy2('/content/beans/'+dtP.loc[i,'filename']+'.jpg', '/content/'+parameter+'/'+str(np.round(dtP.loc[i,parameter],2))+'.jpg')

# %% [markdown]
# ### Removing directory

# %%
#import shutil
#shutil.rmtree('/content/beans/', ignore_errors=True)

# %% [markdown]
# ### Defining regular expression to read L values from images names

# %%
# build a regular expression that extracts the age from file name
PATTERN = r'([^/]+)\d+.jpg$'
import re
p = re.compile(PATTERN)
#r = p.search('UTKFace/30_1_2_20170116191309887.jpg.chip.jpg')
r = p.search('pictures/52.87.jpg')
print("Extracted L:%s" % (float(r.group(1))))

# %% [markdown]
# ### Setting up the default directory

# %% [markdown]
# Set `DATADIR` to the folder where you extracted all the images.

# %%
DATADIR=parameter

# %% [markdown]
# # Building training and validation sets

# %%
data_aug = vis.get_data_aug(horizontal_flip=True, vertical_flip=True)
(train_data, val_data, preproc) = vis.images_from_fname(DATADIR, pattern = PATTERN, data_aug = data_aug, val_pct=0.1,
                                                        is_regression=True, random_state=42)

# %% [markdown]
# # Creating a Model and Wrap in `Learner`

# %%
vis.print_image_regression_models()

# %%
model = vis.image_regression_model('pretrained_resnet50', train_data, val_data)

# %% [markdown]
# ## Wrapping model and data in Learner object

# %%
learner = ktrain.get_learner(model=model, train_data=train_data, val_data=val_data,
                             workers=8, use_multiprocessing=False, batch_size=16)

# %%
learner.model.summary()

# %% [markdown]
# ## Estimating the Learning Rate
#
# We will select a learning rate associated with falling loss from the plot displayed.

# %%
learner.lr_find(max_epochs=2)
learner.lr_plot()

# %% [markdown]
# ## Training Model

# %%
#learner.fit_onecycle(0.001, 15)
learner.autofit(0.005, 20, reduce_on_plateau=3)

# %% [markdown]
# ## Make Predictions
#
# Let's make predictions on individual photos. We could either randomly select from the entire image directory or select just from the validation images.

# %%
# get a Predictor instance that wraps model and Preprocessor object
predictor = ktrain.get_predictor(learner.model, preproc)

# %%
# how to get validation filepaths
val_data.filenames

# %%
def img_prediction(predictor, fname):
    fname = DATADIR+'/'+fname
    predicted = float(predictor.predict_filename(fname)[0])
    actual = float(p.search(fname).group(1))
    #vis.show_image(fname)
    #print('predicted:%s | actual: %s' % (predicted, actual))
    return [predicted, actual]

# %%
re = []
k = 0
for i in val_data.filenames:
  pred, act = img_prediction(predictor, i)
  err = np.abs(pred - act)
  print(k, "-" ,i, err, "-", pred)
  k = k + 1
  re.append(err)

# %%
np.mean(re)

# %%
def show_prediction(predictor, fname):
    print(fname)
    predicted = float(predictor.predict_filename(fname)[0])
    actual = float(p.search(fname).group(1))
    vis.show_image(fname)
    print('predicted:%s | actual: %s' % (predicted, actual))

# %%
show_prediction(predictor, DATADIR +'/'+ val_data.filenames[8])

# %%
#dtP['a'] = np.round(dtP['a'],2)
dtP[dtP['a']==24.01]

# %%
# !pip install git+https://github.com/amaiya/eli5@tfkeras_0_10_1

# %%
predictor.explain( DATADIR +'/'+ val_data.filenames[8])

# %%
# !pip install https://github.com/amaiya/eli5-tf/archive/refs/heads/master.zip

# %% [markdown]
# # Ensemble

# %%
dt = pd.read_csv('/content/beans.csv')

parameters = ['L','a', 'b']
operators = ['min', 'max']

PATTERN = r'([^/]+)\d+.jpg$'

p = re.compile(PATTERN)

import pdb

def buildModel(bean_p, operation, data, PATTERN):

  DATADIR = bean_p+'_'+operation+'/'
  os.makedirs('/content/'+DATADIR)
  print('Estimating '+bean_p+' using '+operation)

  if operation == 'max':
    print('MAX')
    dts = data.groupby(['filename'], as_index=False ).max()
  if operation == 'min':
    print('MIN')
    dts = data.groupby(['filename'], as_index=False ).min()
  if operation == 'mean':
    print('MEAN')
    dts = data.groupby(['filename'], as_index=False ).mean()

  dts = dts[['filename', bean_p]]
  for i in range(dts.shape[0]):
    shutil.copy2('/content/beans/'+dts.loc[i,'filename']+'.jpg', '/content/'+DATADIR+str(np.round(dts.loc[i,bean_p],2))+'.jpg')

  data_aug = vis.get_data_aug(horizontal_flip=True, vertical_flip=True)
  (train_data, val_data, preproc) = vis.images_from_fname(DATADIR, pattern = PATTERN, data_aug = data_aug, val_pct=0.1, is_regression=True, random_state=42)

  model = vis.image_regression_model('default_cnn', train_data, val_data)

  learner = ktrain.get_learner(model=model, train_data=train_data, val_data=val_data, workers=8, use_multiprocessing=False, batch_size=16)
  #learner.fit_onecycle(0.0001, 50)
  learner.autofit(0.05, 30, reduce_on_plateau=3)
  #learner.fit_onecycle(0.0001, 10)

  predictor = ktrain.get_predictor(learner.model, preproc)

  return predictor

# %% [markdown]
# ### Removing testing samples

# %%
def img_prediction(predictor, fname):
    predicted = float(predictor.predict_filename(fname)[0])
    return predicted

# %%
shutil.rmtree('/content/a_min/', ignore_errors=True)
shutil.rmtree('/content/L_min/', ignore_errors=True)
shutil.rmtree('/content/b_min/', ignore_errors=True)
shutil.rmtree('/content/L_max/', ignore_errors=True)
shutil.rmtree('/content/a_max/', ignore_errors=True)
shutil.rmtree('/content/b_max/', ignore_errors=True)

v_ensaios = list(dt['filename'].unique())
v_ensaios = list(dt['filename'].unique())
random.shuffle(v_ensaios)
partitions = [10,10,10,10,10,10,10,10,10,5]
result = pd.DataFrame()

for k in partitions:
  test = v_ensaios[:k]
  print(test)
  del v_ensaios[:k]
  dtTr = dt[~dt['filename'].isin([test])]
  models = []


  x_test = dt[dt['filename'].isin(test)]
  x_test = x_test.groupby(['filename'], as_index=False ).mean()
  re_pi = None
  for pi in parameters:
    re_opi = pd.DataFrame()
    for opi in operators:
      aux = []
      print('Parameter --> '+pi, ' and operator --> ',opi)
      model = buildModel(pi, opi, dtTr, PATTERN)
      for ei in test:
        pred = img_prediction(model, '/content/'+'beans'+'/'+ ei+'.jpg')
        aux.append(pred)
      re_opi = re_opi.append(pd.DataFrame([aux]))
    re_opi = re_opi.mean()

    x_test_pi = x_test[[pi]]
    error = np.abs(x_test_pi[pi] - re_opi)
    re_pi = pd.concat([re_pi, pd.DataFrame(error)], axis=1)
    print(re_pi)
  result = result.append(pd.concat([pd.DataFrame(x_test['filename']),pd.DataFrame(re_pi)], axis=1))




    #re = re.append(pd.DataFrame([ei, pi, np.mean(aux), dt[dt['filename'] == ei][pi].mean(),
    #                          np.abs(np.mean(aux)- dt[dt['filename'] == ei][pi].mean())]).T)
  shutil.rmtree('/content/a_min/', ignore_errors=True)
  shutil.rmtree('/content/L_min/', ignore_errors=True)
  shutil.rmtree('/content/b_min/', ignore_errors=True)
  shutil.rmtree('/content/L_max/', ignore_errors=True)
  shutil.rmtree('/content/a_max/', ignore_errors=True)
  shutil.rmtree('/content/b_max/', ignore_errors=True)
re

# %%
import random
v_ensaios = list(dt['filename'].unique())

# %%
shutil.rmtree('/content/a_min/', ignore_errors=True)
shutil.rmtree('/content/L_min/', ignore_errors=True)
shutil.rmtree('/content/b_min/', ignore_errors=True)
shutil.rmtree('/content/L_max/', ignore_errors=True)
shutil.rmtree('/content/a_max/', ignore_errors=True)
shutil.rmtree('/content/b_max/', ignore_errors=True)

# %%
re.append(pd.DataFrame([ei, pi, np.mean(aux), dt[dt['filename'] == ei][pi].mean(),
                            np.abs(np.mean(aux)- dt[dt['filename'] == ei][pi].mean())]).T)

# %%
def show_prediction(predictor, actual, fname):
    print(fname)
    predicted = float(predictor.predict_filename(fname)[0])
    vis.show_image(fname)
    print('predicted:%s | actual: %s' % (predicted, actual))

# %%
shutil.rmtree('/content/a_min/', ignore_errors=True)
shutil.rmtree('/content/L_max/', ignore_errors=True)

# %%
id = 0
show_prediction(models[0]['model'], dt[dt['filename'] == val_ens[id]]['L'].mean(), '/content/'+'beans'+'/'+ val_ens[id]+'.jpg')

# %%
show_prediction(models[1]['model'], dt[dt['filename'] == val_ens[id]]['L'].mean(), '/content/'+'beans'+'/'+ val_ens[id]+'.jpg')

# %%
show_prediction(models[2]['model'], dt[dt['filename'] == val_ens[id]]['L'].mean(), '/content/'+'beans'+'/'+ val_ens[id]+'.jpg')

# %%
re = pd.DataFrame()
for im in range(0,len(val_ens)):

  for pi in parameters:
    aux = []
    l_i_p = [x['parameter']==pi for x in models]
    l_models_i = np.where(np.array(l_i_p)== True)[0]

    param_models = models[l_models_i[0]:l_models_i[2]+1]
    param_models = param_models[0:2]

    for opi in param_models:
      pred = img_prediction(opi['model'], '/content/'+'beans'+'/'+ val_ens[im]+'.jpg')
      aux.append(pred)
    re = re.append(pd.DataFrame([val_ens[im], pi, np.mean(aux), dt[dt['filename'] == val_ens[im]][opi['parameter']].mean(),
                            np.abs(np.mean(aux)- dt[dt['filename'] == val_ens[im]][opi['parameter']].mean())]).T)

# %%
re.columns = ['filename', 'parameter', 'pred', 'actual', 'error']
re

# %%
models[0:2]

# %%
val_ens
